# %% [markdown]
# <a href="https://colab.research.google.com/github/karsakami/Fullstack-Datascience/blob/main/Decision_Tree_vs_Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #We can say, that random forest is just a set of decision tree models

# %% [markdown]
# ![image.png](data:image/png;base64,...)
